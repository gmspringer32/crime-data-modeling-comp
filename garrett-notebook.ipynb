# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import matplotlib.pyplot as plt

crime1 = pd.read_csv("data/crime1.csv")
crime2 = pd.read_csv("data/crime2.csv")
codes = pd.read_csv("data/Chicago_Police_Department_codes.csv")

# %%
crime = pd.concat([crime1, crime2], axis=0)
violent_crimes_codes = codes.loc[
    (codes["PRIMARY DESCRIPTION"] == "HOMICIDE")
    | (codes["PRIMARY DESCRIPTION"] == "CRIMINAL SEXUAL ASSAULT")
    | (codes["PRIMARY DESCRIPTION"] == "ROBBERY")
    | (codes["PRIMARY DESCRIPTION"] == "BATTERY")
    | (codes["PRIMARY DESCRIPTION"] == "ASSAULT")
    | (codes["IUCR"].isin(["1562", "1563", "1590", "1751", "1752", "1753", "1754"]))
]

violent_crimes = crime.loc[crime["IUCR"].isin(violent_crimes_codes["IUCR"])]

# %%
test = violent_crimes.head(1000)

# %%
fig = px.density_mapbox(
    violent_crimes,
    lat="Latitude",
    lon="Longitude",
    radius=1,
    mapbox_style="open-street-map",
)
fig.show()

# %%
violent_crimes
# Out:
#         Unnamed: 0        ID Case Number                    Date  \
# 3                3  12990873    JG161829  08/17/2019 01:14:00 PM
# 45              45  13193026    JG403252  08/30/2023 12:00:00 AM
# 62              62  13203039    JG414978  09/07/2023 12:45:00 PM
# 74              74  13203952    JG416177  09/08/2023 12:00:00 AM
# 98              98  13203509    JG415610  09/07/2023 05:30:00 PM
# ...            ...       ...         ...                     ...
# 256045      512139  13129724    JG327904  07/04/2023 11:00:00 PM
# 256048      512142  13133105    JG332074  07/07/2023 07:00:00 AM
# 256059      512153  13081120    JG270501  05/22/2023 01:15:00 PM
# 256064      512158  13180525    JG388354  08/18/2023 08:43:00 PM
# 256085      512179  13061873    JG247177  05/03/2023 11:12:00 PM
#
#                           Block  IUCR                Primary Type  \
# 3            008XX N KARLOV AVE  1751  OFFENSE INVOLVING CHILDREN
# 45              011XX S TROY ST  051A                     ASSAULT
# 62      009XX S SACRAMENTO BLVD  051A                     ASSAULT
# 74         006XX N LAWNDALE AVE  031A                     ROBBERY
# 98           009XX N PULASKI RD  1562                 SEX OFFENSE
# ...                         ...   ...                         ...
# 256045     029XX W JACKSON BLVD  051A                     ASSAULT
# 256048        008XX N AVERS AVE  031A                     ROBBERY
# 256059     038XX W ROOSEVELT RD  051A                     ASSAULT
# 256064     039XX W ROOSEVELT RD  051A                     ASSAULT
# 256085         035XX W ADAMS ST  051A                     ASSAULT
#
#                                    Description  \
# 3       CRIMINAL SEXUAL ABUSE BY FAMILY MEMBER
# 45                        AGGRAVATED - HANDGUN
# 62                        AGGRAVATED - HANDGUN
# 74                             ARMED - HANDGUN
# 98            AGGRAVATED CRIMINAL SEXUAL ABUSE
# ...                                        ...
# 256045                    AGGRAVATED - HANDGUN
# 256048                         ARMED - HANDGUN
# 256059                    AGGRAVATED - HANDGUN
# 256064                    AGGRAVATED - HANDGUN
# 256085                    AGGRAVATED - HANDGUN
#
#                           Location Description  Arrest  ...  Ward  \
# 3                                    RESIDENCE    True  ...  37.0
# 45                                   APARTMENT    True  ...  24.0
# 62                                      STREET   False  ...  28.0
# 74                                      STREET   False  ...  27.0
# 98                                 GAS STATION   False  ...  37.0
# ...                                        ...     ...  ...   ...
# 256045                               APARTMENT   False  ...  27.0
# 256048                                  STREET   False  ...  37.0
# 256059                                  STREET   False  ...  24.0
# 256064  PARKING LOT / GARAGE (NON RESIDENTIAL)    True  ...  24.0
# 256085                               APARTMENT    True  ...  28.0
#
#         Community Area  FBI Code  X Coordinate  Y Coordinate  Year  \
# 3                 23.0        17     1148899.0     1905351.0  2019
# 45                29.0       04A     1155533.0     1894984.0  2023
# 62                27.0       04A     1156505.0     1895789.0  2023
# 74                23.0        03     1151604.0     1904073.0  2023
# 98                23.0        17     1149553.0     1905901.0  2023
# ...                ...       ...           ...           ...   ...
# 256045            27.0       04A     1156668.0     1898548.0  2023
# 256048            23.0        03     1150569.0     1905375.0  2023
# 256059            29.0       04A     1151182.0     1894442.0  2023
# 256064            29.0       04A     1150118.0     1894416.0  2023
# 256085            27.0       04A     1152863.0     1898846.0  2023
#
#                     Updated On   Latitude  Longitude  \
# 3       09/14/2023 03:41:59 PM  41.896215 -87.728572
# 45      09/15/2023 03:41:25 PM  41.867636 -87.704486
# 62      09/15/2023 03:42:23 PM  41.869826 -87.700895
# 74      09/15/2023 03:42:23 PM  41.892655 -87.718671
# 98      09/15/2023 03:42:23 PM  41.897712 -87.726156
# ...                        ...        ...        ...
# 256045  08/19/2023 03:40:26 PM  41.877393 -87.700222
# 256048  08/19/2023 03:40:26 PM  41.896249 -87.722438
# 256059  08/19/2023 03:40:26 PM  41.866235 -87.720473
# 256064  08/26/2023 03:42:17 PM  41.866185 -87.724380
# 256085  08/19/2023 03:40:26 PM  41.878287 -87.714185
#
#                              Location
# 3        (41.89621515, -87.728572048)
# 45      (41.867636169, -87.704485536)
# 62      (41.869825578, -87.700895375)
# 74      (41.892655438, -87.718670666)
# 98      (41.897711731, -87.726155718)
# ...                               ...
# 256045   (41.877393256, -87.70022224)
# 256048  (41.896248542, -87.722437789)
# 256059  (41.866235211, -87.720473094)
# 256064  (41.866184642, -87.724379838)
# 256085   (41.87828717, -87.714185338)
#
# [21345 rows x 23 columns]

# %%
fig, ax = plt.subplots(figsize=(8, 5))
ax.plot(violent_crimes[""])
